# %% [markdown]
# # Extracting the morphometric statistics
#
#
# **Please make sure to preprocess the raw-reconstructions using the preprocess-morph-SWC-files.ipynb before running this notebook**

# %%
import pandas as pd
import numpy as np
import copy
import os

from neurontree import NeuronTree as nt
from helpers.morph_features import get_morphometrics

#PLOTTING
import seaborn as sns
import matplotlib.pyplot as plt

# %%
root_path = 'D:/mpinb/data/mouse_v1'
save_path = root_path + '/processed/morph/features/'
path_to_reconstructions = root_path + '/processed/morph/nt/'

# %%
meta_data_file_path = root_path + '/20200711_patchseq_metadata_mouse.csv'
cells = pd.read_csv(meta_data_file_path, sep=',', index_col=1)
cells = cells[cells['neuron_reconstruction_type'] == 'full']

# %%
cells
# Out:
#                      project                         cell_specimen_name  \
# cell_specimen_id
# 601506507         mIVSCC-MET          Vip-IRES-Cre;Ai14-331294.04.01.01
# 601790961         mIVSCC-MET          Sst-IRES-Cre;Ai14-331663.04.01.01
# 601803754         mIVSCC-MET          Sst-IRES-Cre;Ai14-331663.04.02.02
# 601808698         mIVSCC-MET          Sst-IRES-Cre;Ai14-331663.04.02.03
# 601810307         mIVSCC-MET          Sst-IRES-Cre;Ai14-331663.04.02.04
# ...                      ...                                        ...
# 992386952         mIVSCC-MET  Sncg-IRES2-FlpO-neo;Ai65F-499189.04.02.02
# 992830261         mIVSCC-MET  Sncg-IRES2-FlpO-neo;Ai65F-499191.05.02.02
# 993243528         mIVSCC-MET  Sncg-IRES2-FlpO-neo;Ai65F-500414.03.01.01
# 993245688         mIVSCC-MET  Sncg-IRES2-FlpO-neo;Ai65F-500414.05.01.01
# 993283588         mIVSCC-MET  Sncg-IRES2-FlpO-neo;Ai65F-500415.03.02.01
#
#                  hemisphere structure  donor_id  \
# cell_specimen_id
# 601506507              left    VISpm4    331294
# 601790961              left    VISpm5    331663
# 601803754             right   VISp2/3    331663
# 601808698             right     VISp5    331663
# 601810307             right   VISp2/3    331663
# ...                     ...       ...       ...
# 992386952             right     VISl1    499189
# 992830261             right     VISp5    499191
# 993243528              left     VISp1    500414
# 993245688              left   VISp2/3    500414
# 993283588             right   VISp2/3    500415
#
#                                         donor_name biological_sex  age  \
# cell_specimen_id
# 601506507                 Vip-IRES-Cre;Ai14-331294              M  P55
# 601790961                 Sst-IRES-Cre;Ai14-331663              F  P57
# 601803754                 Sst-IRES-Cre;Ai14-331663              F  P57
# 601808698                 Sst-IRES-Cre;Ai14-331663              F  P57
# 601810307                 Sst-IRES-Cre;Ai14-331663              F  P57
# ...                                            ...            ...  ...
# 992386952         Sncg-IRES2-FlpO-neo;Ai65F-499189              F  P60
# 992830261         Sncg-IRES2-FlpO-neo;Ai65F-499191              F  P62
# 993243528         Sncg-IRES2-FlpO-neo;Ai65F-500414              M  P55
# 993245688         Sncg-IRES2-FlpO-neo;Ai65F-500414              M  P55
# 993283588         Sncg-IRES2-FlpO-neo;Ai65F-500415              M  P55
#
#                   ethnicity  medical_conditions  ...   dendrite_type  \
# cell_specimen_id                                 ...
# 601506507               NaN                 NaN  ...  sparsely spiny
# 601790961               NaN                 NaN  ...          aspiny
# 601803754               NaN                 NaN  ...  sparsely spiny
# 601808698               NaN                 NaN  ...          aspiny
# 601810307               NaN                 NaN  ...          aspiny
# ...                     ...                 ...  ...             ...
# 992386952               NaN                 NaN  ...          aspiny
# 992830261               NaN                 NaN  ...          aspiny
# 993243528               NaN                 NaN  ...          aspiny
# 993245688               NaN                 NaN  ...          aspiny
# 993283588               NaN                 NaN  ...          aspiny
#
#                  apical_dendrite_status neuron_reconstruction_type  \
# cell_specimen_id
# 601506507                           NaN                       full
# 601790961                           NaN                       full
# 601803754                           NaN                       full
# 601808698                           NaN                       full
# 601810307                           NaN                       full
# ...                                 ...                        ...
# 992386952                           NaN                       full
# 992830261                           NaN                       full
# 993243528                           NaN                       full
# 993245688                           NaN                       full
# 993283588                           NaN                       full
#
#                  cell_soma_normalized_depth  depth_from_pia_um  \
# cell_specimen_id
# 601506507                          0.361015                NaN
# 601790961                          0.621829                NaN
# 601803754                          0.164240                NaN
# 601808698                          0.483030                NaN
# 601810307                          0.295656                NaN
# ...                                     ...                ...
# 992386952                          0.143579                NaN
# 992830261                          0.691884                NaN
# 993243528                          0.118258                NaN
# 993245688                          0.270298                NaN
# 993283588                          0.207759                NaN
#
#                   ephys_session_id  transcriptomics_sample_id  \
# cell_specimen_id
# 601506507                601506492           PS0810_E1-50_S88
# 601790961                601790945           PS0817_E1-50_S19
# 601803754                601803733           PS0817_E1-50_S25
# 601808698                601808619           PS0817_E1-50_S26
# 601810307                601810292           PS0817_E1-50_S27
# ...                            ...                        ...
# 992386952                992386928        SM-J39ZH_S505_E1-50
# 992830261                992830126        SM-J39ZH_S566_E1-50
# 993243528                993243447        SM-J39TJ_S267_E1-50
# 993245688                993245664        SM-J39TJ_S275_E1-50
# 993283588                993283569        SM-J39TJ_S273_E1-50
#
#                  transcriptomics_batch Tree_first_cl_label         Unnamed: 21
# cell_specimen_id
# 601506507                        BT035      CS180626100018    Vip Gpc3 Slc18a3
# 601790961                        BT036      CS180626100041       Sst Tac2 Myh4
# 601803754                        BT036      CS180626100035    Sst Calb2 Pdlim5
# 601808698                        BT036      CS180626100043      Sst Hpse Cbln4
# 601810307                        BT036      CS180626100034    Sst Calb2 Necab1
# ...                                ...                 ...                 ...
# 992386952                      RSC-240      CS180626100011      Sncg Vip Itih5
# 992830261                      RSC-240      CS180626100008        Sncg Slc17a8
# 993243528                      RSC-242      CS180626100002  Lamp5 Fam19a1 Pax6
# 993245688                      RSC-242      CS180626100010          Sncg Gpr50
# 993283588                      RSC-242      CS180626100010          Sncg Gpr50
#
# [528 rows x 21 columns]

# %%
i = 0
for file_name in list(cells.index):
        
    if not os.path.exists(save_path + str(file_name) + '.csv'):

        print('%i: Calculating morphometric statistics for %s' % (i,file_name))

        # load in data
        swc = pd.read_csv(path_to_reconstructions + str(file_name) + '.swc', 
                          delim_whitespace=True, comment='#',
                              names=['n', 'type', 'x', 'y', 'z', 'radius', 'parent'], index_col=False)
        # create a neurontree
        N = nt.NeuronTree(swc=swc)

        z = dict()
        z['cell id'] = file_name

        # get the morphometrics
        norm_depth = cells.loc[file_name, 'cell_soma_normalized_depth']
        thickness = 1500
        depth = norm_depth * thickness
        d = get_morphometrics(N, depth, thickness)

        z.update(d)

        # save data 
        morphometry_data = pd.DataFrame(z)
        morphometry_data.to_csv(save_path + str(file_name) + ".csv")     

        i+=1       
    else:
        continue
# Out:
# 0: Calculating morphometric statistics for 601506507
# 1: Calculating morphometric statistics for 601790961
# 2: Calculating morphometric statistics for 601803754
# 3: Calculating morphometric statistics for 601808698
# 4: Calculating morphometric statistics for 601810307
# 5: Calculating morphometric statistics for 601811091
# 6: Calculating morphometric statistics for 602231708
# 7: Calculating morphometric statistics for 602535278
# 8: Calculating morphometric statistics for 604646725
# 9: Calculating morphometric statistics for 605060256
# 10: Calculating morphometric statistics for 605160536
# 11: Calculating morphometric statistics for 606098116
# 12: Calculating morphometric statistics for 606271263
# 13: Calculating morphometric statistics for 606308411
# 14: Calculating morphometric statistics for 614728680
# 15: Calculating morphometric statistics for 623326230
# 16: Calculating morphometric statistics for 623415197
# 17: Calculating morphometric statistics for 623434306
# 18: Calculating morphometric statistics for 626153003
# 19: Calculating morphometric statistics for 627881581
# 20: Calculating morphometric statistics for 637846989
# 21: Calculating morphometric statistics for 638212024
# 22: Calculating morphometric statistics for 639004612
# 23: Calculating morphometric statistics for 639013022
# 24: Calculating morphometric statistics for 639674270
# 25: Calculating morphometric statistics for 639708328
# 26: Calculating morphometric statistics for 639797308
# 27: Calculating morphometric statistics for 639809582
# 28: Calculating morphometric statistics for 639818525
# 29: Calculating morphometric statistics for 639841063
# 30: Calculating morphometric statistics for 639862877
# 31: Calculating morphometric statistics for 639881631
# 32: Calculating morphometric statistics for 639893239
# 33: Calculating morphometric statistics for 639962984
# 34: Calculating morphometric statistics for 640061596
# 35: Calculating morphometric statistics for 640111844
# 36: Calculating morphometric statistics for 640280740
# 37: Calculating morphometric statistics for 642124659
# 38: Calculating morphometric statistics for 643021973
# 39: Calculating morphometric statistics for 643536919
# 40: Calculating morphometric statistics for 643702874
# 41: Calculating morphometric statistics for 643727497
# 42: Calculating morphometric statistics for 643754730
# 43: Calculating morphometric statistics for 644571405
# 44: Calculating morphometric statistics for 644920227
# 45: Calculating morphometric statistics for 644941196
# 46: Calculating morphometric statistics for 644994103
# 47: Calculating morphometric statistics for 645012440
# 48: Calculating morphometric statistics for 645057881
# 49: Calculating morphometric statistics for 645169930
# 50: Calculating morphometric statistics for 645322005
# 51: Calculating morphometric statistics for 645355846
# 52: Calculating morphometric statistics for 646805498
# 53: Calculating morphometric statistics for 646852171
# 54: Calculating morphometric statistics for 647045788
# 55: Calculating morphometric statistics for 648139266
# 56: Calculating morphometric statistics for 648582997
# 57: Calculating morphometric statistics for 649387261
# 58: Calculating morphometric statistics for 652299236
# 59: Calculating morphometric statistics for 652300499
# 60: Calculating morphometric statistics for 652305423
# 61: Calculating morphometric statistics for 652306478
# 62: Calculating morphometric statistics for 652516963
# 63: Calculating morphometric statistics for 652533530
# 64: Calculating morphometric statistics for 652812484
# 65: Calculating morphometric statistics for 652958762
# 66: Calculating morphometric statistics for 653327513
# 67: Calculating morphometric statistics for 653699672
# 68: Calculating morphometric statistics for 656156755
# 69: Calculating morphometric statistics for 656705176
# 70: Calculating morphometric statistics for 656706125
# 71: Calculating morphometric statistics for 656901554
# 72: Calculating morphometric statistics for 657184390
# 73: Calculating morphometric statistics for 657185355
# 74: Calculating morphometric statistics for 657442490
# 75: Calculating morphometric statistics for 657454163
# 76: Calculating morphometric statistics for 657661669
# 77: Calculating morphometric statistics for 657661984
# 78: Calculating morphometric statistics for 657675492
# 79: Calculating morphometric statistics for 657857340
# 80: Calculating morphometric statistics for 657858349
# 81: Calculating morphometric statistics for 657983207
# 82: Calculating morphometric statistics for 657984709
# 83: Calculating morphometric statistics for 657985196
# 84: Calculating morphometric statistics for 657999088
# 85: Calculating morphometric statistics for 658012080
# 86: Calculating morphometric statistics for 658447323
# 87: Calculating morphometric statistics for 659012847
# 88: Calculating morphometric statistics for 659395808
# 89: Calculating morphometric statistics for 659405820
# 90: Calculating morphometric statistics for 659405868
# 91: Calculating morphometric statistics for 659413418
# 92: Calculating morphometric statistics for 659697295
# 93: Calculating morphometric statistics for 660050258
# 94: Calculating morphometric statistics for 661189529
# 95: Calculating morphometric statistics for 661318431
# 96: Calculating morphometric statistics for 661319074
# 97: Calculating morphometric statistics for 661422439
# 98: Calculating morphometric statistics for 661492805
# 99: Calculating morphometric statistics for 662580082
# 100: Calculating morphometric statistics for 663193112
# 101: Calculating morphometric statistics for 666141992
# 102: Calculating morphometric statistics for 667473785
# 103: Calculating morphometric statistics for 667492234
# 104: Calculating morphometric statistics for 668176228
# 105: Calculating morphometric statistics for 668337999
# 106: Calculating morphometric statistics for 668464797
# 107: Calculating morphometric statistics for 669047778
# 108: Calculating morphometric statistics for 669072736
# 109: Calculating morphometric statistics for 669074640
# 110: Calculating morphometric statistics for 669088423
# 111: Calculating morphometric statistics for 669165397
# 112: Calculating morphometric statistics for 669523148
# 113: Calculating morphometric statistics for 669825289
# 114: Calculating morphometric statistics for 669838950
# 115: Calculating morphometric statistics for 670091720
# 116: Calculating morphometric statistics for 670340941
# 117: Calculating morphometric statistics for 673132928
# 118: Calculating morphometric statistics for 673395815
# 119: Calculating morphometric statistics for 673427380
# 120: Calculating morphometric statistics for 674069192
# 121: Calculating morphometric statistics for 674126167
# 122: Calculating morphometric statistics for 674495385
# 123: Calculating morphometric statistics for 679457550
# 124: Calculating morphometric statistics for 679899997
# 125: Calculating morphometric statistics for 679932490
# 126: Calculating morphometric statistics for 680027413
# 127: Calculating morphometric statistics for 680048186
# 128: Calculating morphometric statistics for 680108584
# 129: Calculating morphometric statistics for 681793778
# 130: Calculating morphometric statistics for 682332013
# 131: Calculating morphometric statistics for 682454193
# 132: Calculating morphometric statistics for 683899155
# 133: Calculating morphometric statistics for 685624703
# 134: Calculating morphometric statistics for 685636842
# 135: Calculating morphometric statistics for 685707621
# 136: Calculating morphometric statistics for 687907602
# 137: Calculating morphometric statistics for 688115867
# 138: Calculating morphometric statistics for 688145929
# 139: Calculating morphometric statistics for 688958418
# 140: Calculating morphometric statistics for 689030611
# 141: Calculating morphometric statistics for 689098357
# 142: Calculating morphometric statistics for 689211404
# 143: Calculating morphometric statistics for 689280134
# 144: Calculating morphometric statistics for 689656936
# 145: Calculating morphometric statistics for 691511791
# 146: Calculating morphometric statistics for 691665864
# 147: Calculating morphometric statistics for 691685873
# 148: Calculating morphometric statistics for 691719142
# 149: Calculating morphometric statistics for 692015490
# 150: Calculating morphometric statistics for 692044280
# 151: Calculating morphometric statistics for 692083084
# 152: Calculating morphometric statistics for 692286150
# 153: Calculating morphometric statistics for 692565557
# 154: Calculating morphometric statistics for 692777680
# 155: Calculating morphometric statistics for 692821749
# 156: Calculating morphometric statistics for 692824134
# 157: Calculating morphometric statistics for 692846027
# 158: Calculating morphometric statistics for 693009119
# 159: Calculating morphometric statistics for 693085460
# 160: Calculating morphometric statistics for 693265371
# 161: Calculating morphometric statistics for 694146546
# 162: Calculating morphometric statistics for 694162255
# 163: Calculating morphometric statistics for 694183636
# 164: Calculating morphometric statistics for 694220357
# 165: Calculating morphometric statistics for 694419620
# 166: Calculating morphometric statistics for 694437359
# 167: Calculating morphometric statistics for 694689662
# 168: Calculating morphometric statistics for 694734857
# 169: Calculating morphometric statistics for 695316536
# 170: Calculating morphometric statistics for 696115308
# 171: Calculating morphometric statistics for 697502029
# 172: Calculating morphometric statistics for 697787349
# 173: Calculating morphometric statistics for 697795277
# 174: Calculating morphometric statistics for 697799017
# 175: Calculating morphometric statistics for 697810838
# 176: Calculating morphometric statistics for 698042345
# 177: Calculating morphometric statistics for 698086962
# 178: Calculating morphometric statistics for 698570301
# 179: Calculating morphometric statistics for 698586385
# 180: Calculating morphometric statistics for 699448311
# 181: Calculating morphometric statistics for 699495755
# 182: Calculating morphometric statistics for 700390241
# 183: Calculating morphometric statistics for 700413526
# 184: Calculating morphometric statistics for 701075567
# 185: Calculating morphometric statistics for 701140434
# 186: Calculating morphometric statistics for 702051128
# 187: Calculating morphometric statistics for 703283610
# 188: Calculating morphometric statistics for 703565379
# 189: Calculating morphometric statistics for 704047023
# 190: Calculating morphometric statistics for 705217315
# 191: Calculating morphometric statistics for 705278421
# 192: Calculating morphometric statistics for 705570328
# 193: Calculating morphometric statistics for 705817510
# 194: Calculating morphometric statistics for 707162377
# 195: Calculating morphometric statistics for 707179690
# 196: Calculating morphometric statistics for 707403326
# 197: Calculating morphometric statistics for 707424705
# 198: Calculating morphometric statistics for 707666779
# 199: Calculating morphometric statistics for 708221965
# 200: Calculating morphometric statistics for 709153201
# 201: Calculating morphometric statistics for 709219898
# 202: Calculating morphometric statistics for 710338421
# 203: Calculating morphometric statistics for 710730520
# 204: Calculating morphometric statistics for 710743304
# 205: Calculating morphometric statistics for 710784375
# 206: Calculating morphometric statistics for 710920450
# 207: Calculating morphometric statistics for 711212623
# 208: Calculating morphometric statistics for 711464852
# 209: Calculating morphometric statistics for 711483278
# 210: Calculating morphometric statistics for 711528753
# 211: Calculating morphometric statistics for 711571947
# 212: Calculating morphometric statistics for 711770582
# 213: Calculating morphometric statistics for 711903629
# 214: Calculating morphometric statistics for 713132614
# 215: Calculating morphometric statistics for 713442456
# 216: Calculating morphometric statistics for 714046701
# 217: Calculating morphometric statistics for 714228701
# 218: Calculating morphometric statistics for 714485370
# 219: Calculating morphometric statistics for 714601733
# 220: Calculating morphometric statistics for 714755043
# 221: Calculating morphometric statistics for 714936352
# 222: Calculating morphometric statistics for 715159651
# 223: Calculating morphometric statistics for 716298521
# 224: Calculating morphometric statistics for 716832846
# 225: Calculating morphometric statistics for 717637005
# 226: Calculating morphometric statistics for 717675736
# 227: Calculating morphometric statistics for 718135969
# 228: Calculating morphometric statistics for 718188717
# 229: Calculating morphometric statistics for 718195284
# 230: Calculating morphometric statistics for 718202813
# 231: Calculating morphometric statistics for 718205473
# 232: Calculating morphometric statistics for 718237581
# 233: Calculating morphometric statistics for 718257664
# 234: Calculating morphometric statistics for 718494231
# 235: Calculating morphometric statistics for 718618263
# 236: Calculating morphometric statistics for 718636190
# 237: Calculating morphometric statistics for 718640845
# 238: Calculating morphometric statistics for 718643723
# 239: Calculating morphometric statistics for 718644056
# 240: Calculating morphometric statistics for 718647510
# 241: Calculating morphometric statistics for 718656998
# 242: Calculating morphometric statistics for 718872930
# 243: Calculating morphometric statistics for 720186469
# 244: Calculating morphometric statistics for 720207494
# 245: Calculating morphometric statistics for 720318238
# 246: Calculating morphometric statistics for 720678722
# 247: Calculating morphometric statistics for 722795299
# 248: Calculating morphometric statistics for 722821387
# 249: Calculating morphometric statistics for 728756295
# 250: Calculating morphometric statistics for 729135271
# 251: Calculating morphometric statistics for 730744363
# 252: Calculating morphometric statistics for 730796336
# 253: Calculating morphometric statistics for 731651186
# 254: Calculating morphometric statistics for 731683221
# 255: Calculating morphometric statistics for 731733715
# 256: Calculating morphometric statistics for 731765828
# 257: Calculating morphometric statistics for 731882356
# 258: Calculating morphometric statistics for 731917470
# 259: Calculating morphometric statistics for 736884821
# 260: Calculating morphometric statistics for 738041476
# 261: Calculating morphometric statistics for 738043822
# 262: Calculating morphometric statistics for 738401019
# 263: Calculating morphometric statistics for 738859085
# 264: Calculating morphometric statistics for 739539292
# 265: Calculating morphometric statistics for 739547189
# 266: Calculating morphometric statistics for 739558698
# 267: Calculating morphometric statistics for 739570508
# 268: Calculating morphometric statistics for 739792780
# 269: Calculating morphometric statistics for 739810705
# 270: Calculating morphometric statistics for 740094065
# 271: Calculating morphometric statistics for 740110275
# 272: Calculating morphometric statistics for 740134630
# 273: Calculating morphometric statistics for 740135032
# 274: Calculating morphometric statistics for 740155221
# 275: Calculating morphometric statistics for 740164794
# 276: Calculating morphometric statistics for 740380531
# 277: Calculating morphometric statistics for 740649731
# 278: Calculating morphometric statistics for 740660643
# 279: Calculating morphometric statistics for 740675145
# 280: Calculating morphometric statistics for 740695122
# 281: Calculating morphometric statistics for 740732467
# 282: Calculating morphometric statistics for 740780456
# 283: Calculating morphometric statistics for 740819727
# 284: Calculating morphometric statistics for 740872967
# 285: Calculating morphometric statistics for 740875222
# 286: Calculating morphometric statistics for 740890186
# 287: Calculating morphometric statistics for 741187985
# 288: Calculating morphometric statistics for 741313892
# 289: Calculating morphometric statistics for 741785767
# 290: Calculating morphometric statistics for 741788179
# 291: Calculating morphometric statistics for 741796557
# 292: Calculating morphometric statistics for 741940660
# 293: Calculating morphometric statistics for 742009621
# 294: Calculating morphometric statistics for 742033571
# 295: Calculating morphometric statistics for 742784488
# 296: Calculating morphometric statistics for 743001170
# 297: Calculating morphometric statistics for 743012953
# 298: Calculating morphometric statistics for 743041228
# 299: Calculating morphometric statistics for 743049614
# 300: Calculating morphometric statistics for 743458377
# 301: Calculating morphometric statistics for 743468218
# 302: Calculating morphometric statistics for 743504177
# 303: Calculating morphometric statistics for 744053590
# 304: Calculating morphometric statistics for 744211669
# 305: Calculating morphometric statistics for 744454952
# 306: Calculating morphometric statistics for 744476851
# 307: Calculating morphometric statistics for 744975652
# 308: Calculating morphometric statistics for 745584401
# 309: Calculating morphometric statistics for 745633800
# 310: Calculating morphometric statistics for 745692039
# 311: Calculating morphometric statistics for 745736817
# 312: Calculating morphometric statistics for 746086313
# 313: Calculating morphometric statistics for 746200101
# 314: Calculating morphometric statistics for 746257405
# 315: Calculating morphometric statistics for 746732672
# 316: Calculating morphometric statistics for 746747868
# 317: Calculating morphometric statistics for 746754997
# 318: Calculating morphometric statistics for 746917764
# 319: Calculating morphometric statistics for 746924803
# 320: Calculating morphometric statistics for 747028632
# 321: Calculating morphometric statistics for 750472605
# 322: Calculating morphometric statistics for 750706642
# 323: Calculating morphometric statistics for 750776506
# 324: Calculating morphometric statistics for 750824726
# 325: Calculating morphometric statistics for 750833190
# 326: Calculating morphometric statistics for 751199266
# 327: Calculating morphometric statistics for 751947558
# 328: Calculating morphometric statistics for 751991773
# 329: Calculating morphometric statistics for 752027250
# 330: Calculating morphometric statistics for 752042986
# 331: Calculating morphometric statistics for 752063316
# 332: Calculating morphometric statistics for 754508194
# 333: Calculating morphometric statistics for 755552030
# 334: Calculating morphometric statistics for 755592855
# 335: Calculating morphometric statistics for 755625739
# 336: Calculating morphometric statistics for 755625849
# 337: Calculating morphometric statistics for 758263126
# 338: Calculating morphometric statistics for 759751429
# 339: Calculating morphometric statistics for 759909292
# 340: Calculating morphometric statistics for 759939473
# 341: Calculating morphometric statistics for 759948010
# 342: Calculating morphometric statistics for 759955697
# 343: Calculating morphometric statistics for 759970262
# 344: Calculating morphometric statistics for 760011270
# 345: Calculating morphometric statistics for 760064682
# 346: Calculating morphometric statistics for 760268259
# 347: Calculating morphometric statistics for 760280955
# 348: Calculating morphometric statistics for 760294832
# 349: Calculating morphometric statistics for 760316107
# 350: Calculating morphometric statistics for 760416458
# 351: Calculating morphometric statistics for 760437219
# 352: Calculating morphometric statistics for 760821319
# 353: Calculating morphometric statistics for 760832993
# 354: Calculating morphometric statistics for 760834631
# 355: Calculating morphometric statistics for 760890074
# 356: Calculating morphometric statistics for 760961855
# 357: Calculating morphometric statistics for 760981484
# 358: Calculating morphometric statistics for 761297232
# 359: Calculating morphometric statistics for 761304075
# 360: Calculating morphometric statistics for 761344650
# 361: Calculating morphometric statistics for 761409397
# 362: Calculating morphometric statistics for 761429710
# 363: Calculating morphometric statistics for 761820827
# 364: Calculating morphometric statistics for 761822060
# 365: Calculating morphometric statistics for 762590075
# 366: Calculating morphometric statistics for 762757594
# 367: Calculating morphometric statistics for 763378303
# 368: Calculating morphometric statistics for 763912380
# 369: Calculating morphometric statistics for 763952780
# 370: Calculating morphometric statistics for 764341238
# 371: Calculating morphometric statistics for 764391439
# 372: Calculating morphometric statistics for 764726542
# 373: Calculating morphometric statistics for 764872932
# 374: Calculating morphometric statistics for 764879591
# 375: Calculating morphometric statistics for 764896381
# 376: Calculating morphometric statistics for 764897253
# 377: Calculating morphometric statistics for 764902677
# 378: Calculating morphometric statistics for 764902707
# 379: Calculating morphometric statistics for 766097293
# 380: Calculating morphometric statistics for 766591236
# 381: Calculating morphometric statistics for 768763533
# 382: Calculating morphometric statistics for 770216620
# 383: Calculating morphometric statistics for 770238836
# 384: Calculating morphometric statistics for 778327002
# 385: Calculating morphometric statistics for 779708399
# 386: Calculating morphometric statistics for 780005520
# 387: Calculating morphometric statistics for 786135798
# 388: Calculating morphometric statistics for 786176775
# 389: Calculating morphometric statistics for 786228558
# 390: Calculating morphometric statistics for 788296224
# 391: Calculating morphometric statistics for 795530674
# 392: Calculating morphometric statistics for 795563325
# 393: Calculating morphometric statistics for 795572082
# 394: Calculating morphometric statistics for 795844214
# 395: Calculating morphometric statistics for 796636728
# 396: Calculating morphometric statistics for 796666943
# 397: Calculating morphometric statistics for 797664123
# 398: Calculating morphometric statistics for 797722932
# 399: Calculating morphometric statistics for 799776604
# 400: Calculating morphometric statistics for 803605276
# 401: Calculating morphometric statistics for 804968066
# 402: Calculating morphometric statistics for 804977071
# 403: Calculating morphometric statistics for 805584825
# 404: Calculating morphometric statistics for 808285808
# 405: Calculating morphometric statistics for 808475329
# 406: Calculating morphometric statistics for 808537562
# 407: Calculating morphometric statistics for 808824183
# 408: Calculating morphometric statistics for 808875776
# 409: Calculating morphometric statistics for 808882292
# 410: Calculating morphometric statistics for 809006343
# 411: Calculating morphometric statistics for 809113087
# 412: Calculating morphometric statistics for 809338969
# 413: Calculating morphometric statistics for 809649556
# 414: Calculating morphometric statistics for 809688289
# 415: Calculating morphometric statistics for 810317285
# 416: Calculating morphometric statistics for 812996960
# 417: Calculating morphometric statistics for 813500978
# 418: Calculating morphometric statistics for 816012073
# 419: Calculating morphometric statistics for 816434177
# 420: Calculating morphometric statistics for 817935092
# 421: Calculating morphometric statistics for 818792182
# 422: Calculating morphometric statistics for 820754704
# 423: Calculating morphometric statistics for 820897104
# 424: Calculating morphometric statistics for 821563005
# 425: Calculating morphometric statistics for 821771315
# 426: Calculating morphometric statistics for 821774757
# 427: Calculating morphometric statistics for 821788449
# 428: Calculating morphometric statistics for 821907565
# 429: Calculating morphometric statistics for 823253200
# 430: Calculating morphometric statistics for 823681740
# 431: Calculating morphometric statistics for 823702943
# 432: Calculating morphometric statistics for 823719680
# 433: Calculating morphometric statistics for 823830483
# 434: Calculating morphometric statistics for 824909637
# 435: Calculating morphometric statistics for 825269133
# 436: Calculating morphometric statistics for 825522397
# 437: Calculating morphometric statistics for 825549510
# 438: Calculating morphometric statistics for 826712572
# 439: Calculating morphometric statistics for 827347629
# 440: Calculating morphometric statistics for 827447865
# 441: Calculating morphometric statistics for 827524052
# 442: Calculating morphometric statistics for 827573535
# 443: Calculating morphometric statistics for 828803869
# 444: Calculating morphometric statistics for 829170676
# 445: Calculating morphometric statistics for 829185764
# 446: Calculating morphometric statistics for 829195312
# 447: Calculating morphometric statistics for 830434392
# 448: Calculating morphometric statistics for 831988252
# 449: Calculating morphometric statistics for 836844418
# 450: Calculating morphometric statistics for 837594867
# 451: Calculating morphometric statistics for 841718359
# 452: Calculating morphometric statistics for 841834394
# 453: Calculating morphometric statistics for 842841654
# 454: Calculating morphometric statistics for 842844583
# 455: Calculating morphometric statistics for 843366621
# 456: Calculating morphometric statistics for 844757902
# 457: Calculating morphometric statistics for 844870606
# 458: Calculating morphometric statistics for 844965212
# 459: Calculating morphometric statistics for 846902552
# 460: Calculating morphometric statistics for 847083836
# 461: Calculating morphometric statistics for 849535368
# 462: Calculating morphometric statistics for 849607183
# 463: Calculating morphometric statistics for 851016910
# 464: Calculating morphometric statistics for 853882442
# 465: Calculating morphometric statistics for 855275163
# 466: Calculating morphometric statistics for 855357345
# 467: Calculating morphometric statistics for 855791035
# 468: Calculating morphometric statistics for 857223181
# 469: Calculating morphometric statistics for 857296784
# 470: Calculating morphometric statistics for 858255768
# 471: Calculating morphometric statistics for 859621160
# 472: Calculating morphometric statistics for 859655391
# 473: Calculating morphometric statistics for 861736319
# 474: Calculating morphometric statistics for 861765455
# 475: Calculating morphometric statistics for 861769605
# 476: Calculating morphometric statistics for 862596299
# 477: Calculating morphometric statistics for 863585604
# 478: Calculating morphometric statistics for 863604233
# 479: Calculating morphometric statistics for 863631899
# 480: Calculating morphometric statistics for 866267921
# 481: Calculating morphometric statistics for 869634031
# 482: Calculating morphometric statistics for 870661094
# 483: Calculating morphometric statistics for 871782504
# 484: Calculating morphometric statistics for 872026690
# 485: Calculating morphometric statistics for 872248529
# 486: Calculating morphometric statistics for 873854264
# 487: Calculating morphometric statistics for 886335606
# 488: Calculating morphometric statistics for 887048277
# 489: Calculating morphometric statistics for 887156236
# 490: Calculating morphometric statistics for 887288382
# 491: Calculating morphometric statistics for 888108541
# 492: Calculating morphometric statistics for 889183564
# 493: Calculating morphometric statistics for 889235347
# 494: Calculating morphometric statistics for 892547707
# 495: Calculating morphometric statistics for 895740736
# 496: Calculating morphometric statistics for 898559010
# 497: Calculating morphometric statistics for 898697809
# 498: Calculating morphometric statistics for 898703349
# 499: Calculating morphometric statistics for 899368360
# 500: Calculating morphometric statistics for 904023586
# 501: Calculating morphometric statistics for 904832267
# 502: Calculating morphometric statistics for 904862358
# 503: Calculating morphometric statistics for 912868696
# 504: Calculating morphometric statistics for 913928092
# 505: Calculating morphometric statistics for 919102928
# 506: Calculating morphometric statistics for 919950532
# 507: Calculating morphometric statistics for 922613228
# 508: Calculating morphometric statistics for 926866005
# 509: Calculating morphometric statistics for 926887643
# 510: Calculating morphometric statistics for 927833265
# 511: Calculating morphometric statistics for 935032340
# 512: Calculating morphometric statistics for 941794256
# 513: Calculating morphometric statistics for 941802910
# 514: Calculating morphometric statistics for 941824942
# 515: Calculating morphometric statistics for 941846857
# 516: Calculating morphometric statistics for 941868688
# 517: Calculating morphometric statistics for 941935110
# 518: Calculating morphometric statistics for 946190769
# 519: Calculating morphometric statistics for 952669499
# 520: Calculating morphometric statistics for 958930508
# 521: Calculating morphometric statistics for 963019667
# 522: Calculating morphometric statistics for 992268582
# 523: Calculating morphometric statistics for 992386952
# 524: Calculating morphometric statistics for 992830261
# 525: Calculating morphometric statistics for 993243528
# 526: Calculating morphometric statistics for 993245688
# 527: Calculating morphometric statistics for 993283588

# %% [markdown]
# # Explore morphometric features

# %%
data_path = save_path

# load in all morphometrics files into one data frame
morphometrics = pd.DataFrame()
root, _, files = list(os.walk(data_path))[0]
for f in files:
    temp = pd.read_csv(data_path+f, index_col=0)
    morphometrics = morphometrics.append(temp)

morphometrics = morphometrics.reset_index()
del morphometrics['index']

# %%
full_idx = list(morphometrics.columns)
full_idx.remove('cell id')
full_idx.remove('dendrite z-profile')
full_idx.remove('axon z-profile')
full_idx.remove('axon soma-centered z-profile')
full_idx.remove('dendrite soma-centered z-profile')
len(full_idx)
# Out:
# 75

# %% [markdown]
# ## Inhibitory cells

# %%
# get only inhibitory cells
inhibitory_cells = morphometrics.set_index('cell id')
len(full_idx)
# Out:
# 75

# %%
idx_inh_morphometrics = copy.copy(full_idx)
indices, counts = np.unique(np.where(inhibitory_cells[full_idx].isnull())[1], return_counts=True)

to_remove = [idx_inh_morphometrics[z] for z in indices[counts> 100]]
to_remove += [k for k in morphometrics.columns if k.find('"apical"')>-1 ]
to_remove += ['axon depth', 'axon robust depth', 'dendrite depth', 'dendrite robust depth']
for z in set(to_remove):
    print('deleting %s'%z)
    idx_inh_morphometrics.remove(z)
# Out:
# deleting "apical" mean bifurcation distance
# deleting "apical" branch points
# deleting "apical" log1p number of outer bifurcations
# deleting axon robust depth
# deleting "apical" std bifurcation distance
# deleting axon depth
# deleting "apical" height
# deleting "apical" width
# deleting dendrite depth
# deleting "apical" robust width
# deleting "apical" robust height
# deleting "apical" total length
# deleting dendrite robust depth

# %%
inhibitory_cells = inhibitory_cells[idx_inh_morphometrics]

# # morphometrics to be excluded due to little variation
# print('Features excluded due to little variation: \n', np.array(idx_inh_morphometrics)[(inhibitory_cells.abs().std()/inhibitory_cells.abs().mean() < 0.25).values])

# idx_after_cv = np.array(idx_inh_morphometrics)[(inhibitory_cells.abs().std()/inhibitory_cells.abs().mean() >= 0.25).values]
# print('remaining features: \n', idx_after_cv, ' \n number of features: ', len(idx_after_cv))
len(idx_inh_morphometrics)
# Out:
# 62

# %%
# final_inh_idx = list(idx_after_cv)

# exclude features after visual inspection
# to_remove = [ 'Log1p fraction of dendrite below axon',
#              'dendrite max branch angle', 'dendrite min branch angle']

# for z in to_remove:
#     final_inh_idx.remove(z)

# print('Final number of inhibitory features: ', len(final_inh_idx))

# %% [markdown]
# # Concatenate and store the features
#
# ## Morphometric statistics

# %%
morphometric_used = inhibitory_cells[idx_inh_morphometrics]
morphometric_used.to_csv(save_path + '/../v1_patchseq_morph_features.csv')

# %% [markdown]
# ## z-profiles

# %%
inhibitory_cells = morphometrics.set_index('cell id')
    
# first load them assigned to their index/name. Then put them in an array. To make sure they correspond. 
profile_dict_i=dict()
for rn,item in list(inhibitory_cells.iterrows()):
    profile_dict_i[rn] = np.array([])
    for profile in item[['axon z-profile']]:
        if profile is not np.nan:
            s = profile.replace('\n', '').replace('[', '').replace(']','')
            no = [x for x in s.split(' ') if x != '']
            temp = np.array([float(n) for n in no])
        else:
            temp = np.zeros((1,20))
        
        if profile_dict_i[rn].size == 0:
            profile_dict_i[rn] = temp
        else:  
            profile_dict_i[rn] = np.vstack((profile_dict_i[rn],temp))

# %%
z_profiles = pd.DataFrame(profile_dict_i).T
z_profiles = z_profiles.reset_index().rename(columns={'index':'cell id'}).set_index('cell id')
z_profiles.to_csv(save_path + '/../v1_patchseq_morph_zprofiles.csv')
